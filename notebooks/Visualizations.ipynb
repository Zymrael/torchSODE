# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LightSource
from matplotlib import cm

# %%
file = open("traj.txt", 'r')

# %%
xi = []

# %%
for idx, line in enumerate(file):
    for i in range(3):       
        xi.append([float(el) for el in line.split('\t') if el != '\n'])

# %%
plt.plot(xi)
# Out:
# [<matplotlib.lines.Line2D at 0x7f4cc08060b8>,
#  <matplotlib.lines.Line2D at 0x7f4cc0806240>,
#  <matplotlib.lines.Line2D at 0x7f4cc0806390>]

# %%
x, y, z = [el[0] for el in xi], [el[1] for el in xi], [el[2] for el in xi]
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(x, y, z, lw=0.4, color='black')
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")
plt.show()
